# %% [markdown]
# # AI Tokens

# %% [markdown]
# words are convered to vector of numbers ( using mathematical operations eg Ascii / bit conversions )
# #### token -> a small piece of text the model reads before it turns that piece into a number

# %% [markdown]
# ## hello ?  -> 3 tokens  "hello"," ","?"

# %% [markdown]
# #### then tokens -> vector of numbers -> embeddings using embedding techniques -> model -> embeddings -> tokens -> output
# ### apple = [0.21,0.45,0.08 ...............]

# %% [markdown]
# ### Each model has its own tokenizer

# %% [markdown]
# ### TPS ( Tokens per Second )

# %% [markdown]
# ## every token is billed

# %% [markdown]
# ## context window

# %% [markdown]
# ### every model has its own context window, number of tokens we can send / memorize in a single session
