# %% [markdown]
# ## EDA: Exploratory DATA Analysis
# #### Business understanding -> Data understanding -> Data collection -> Data preparation ( unclean -> clean data ) -> EDA -> Insights
# #### use cases:
#  ##### To prepare data for machine learning models

# %% [markdown]
# ### EDA:
# #### TO analyze the dataset to summarize their main characterstics in form of visual methods ( to obtain confidence in the data )
# #### to find errors discovering data mapping out data structure, finding out anamolies

# %% [markdown]
# ## Data sourcing
# Collecting data from various sources
# public / private data
# #### Data Cleaning :
# unclean -> clean  ( handle missing values , standardization of data, outlier treatment, handle invalid values )

# %% [markdown]
# ### Handling missing values
# 1. Delete rows / columns : column can be deleted if it has more than 75% missing values, rows -> if it has insignificant number of missing values
#    imputing ->
# 2. Replacing with missing values -> filling with random values / mean / median, mode -> categorical data, will decide based on accuracy.
# 3. In certain we will go ahead with algorithamic way of filling missing values ( algorithimic imputation )
# 4. predicting the missing values ( if the recod has 800 values we will take 800 to predict missing values for 200 values )

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\DataScience\Desktop\DATA_SCIENCE\EDA\EDA-main\Data\Churn_Modelling.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           9946 non-null   object
#  6   Age              9880 non-null   float64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
## finding the null values  count

df.isnull().sum()
# Out:
# RowNumber            0
# CustomerId           0
# Surname              0
# CreditScore          0
# Geography            0
# Gender              54
# Age                120
# Tenure               0
# Balance              0
# NumOfProducts        0
# HasCrCard            0
# IsActiveMember       0
# EstimatedSalary      0
# Exited               0
# dtype: int64

# %%
# deleting columns with missing data

# %%
updated_df = df.dropna(axis=1)
updated_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Tenure           10000 non-null  int64
#  6   Balance          10000 non-null  float64
#  7   NumOfProducts    10000 non-null  int64
#  8   HasCrCard        10000 non-null  int64
#  9   IsActiveMember   10000 non-null  int64
#  10  EstimatedSalary  10000 non-null  float64
#  11  Exited           10000 non-null  int64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 937.6+ KB

# %%
# deleting rows with missing values

updated_df=df.dropna(axis=0)
updated_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9830 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        9830 non-null   int64
#  1   CustomerId       9830 non-null   int64
#  2   Surname          9830 non-null   object
#  3   CreditScore      9830 non-null   int64
#  4   Geography        9830 non-null   object
#  5   Gender           9830 non-null   object
#  6   Age              9830 non-null   float64
#  7   Tenure           9830 non-null   int64
#  8   Balance          9830 non-null   float64
#  9   NumOfProducts    9830 non-null   int64
#  10  HasCrCard        9830 non-null   int64
#  11  IsActiveMember   9830 non-null   int64
#  12  EstimatedSalary  9830 non-null   float64
#  13  Exited           9830 non-null   int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
# Filling the missing values 
#imputation

df['Age'].mean()
# Out:
# np.float64(38.925)

# %%
df['Gender'].mode()
# Out:
# 0    Male
# Name: Gender, dtype: object

# %%
#filing the null records
# filling with mean values
updated_df=df
updated_df['Age']=updated_df['Age'].fillna(df['Age'].mean())
updated_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           9946 non-null   object
#  6   Age              10000 non-null  float64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
# filling with median 

updated_df1=df
updated_df1['Age']=updated_df['Age'].fillna(df['Age'].median())
updated_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           9946 non-null   object
#  6   Age              10000 non-null  float64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# # forward and Backward filling

# %%
# filled with next / previous values

# %%
updated_df1=df
updated_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           9946 non-null   object
#  6   Age              10000 non-null  float64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
updated_df['Age']=updated_df['Age'].bfill() #backward fill
updated_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           9946 non-null   object
#  6   Age              10000 non-null  float64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
updated_df1=df
updated_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           9946 non-null   object
#  6   Age              10000 non-null  float64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           9946 non-null   object
#  6   Age              10000 non-null  float64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# #### Feature Scaling
# ##### When we are dealing with a dataset containing features in terms of range of values / units
# ##### then we have to normalize / standardize the data such that the data doesn't effect the outcome
# ##### so that the difference in the scale doesn't effect the outcome
# ##### predictive modeling predictive analysis
#
# #### Normalization is a data preprocessing technique that rescales data into a fixed range, usually: 0 and 1
# #### Standardization is a data preprocessing technique that transforms data so that it has:
#
# #### Mean = 0
# #### Standard deviation = 1

# %% [markdown]
# #### Formula
# ##### Standard scaler (digestion): Z= ((x-u(mean)) / Standard Deviation)
# ##### Min-Max Scaler(Normalisation) :  X  = (x-Xmin)/(Xmax-Xmin)
# #### for standardised data mean will be almost zero
# #### standardization is done based on standard normal distribution

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\DataScience\Desktop\DATA_SCIENCE\EDA\EDA-main\Data\Churn_Modelling.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           9946 non-null   object
#  6   Age              9880 non-null   float64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## Normalization
# #### min max scaler scaling the values between 0 and 1
# ## Standardization
# #### Scaling technique where the values are centered around the mean with a unit standard deviation

# %%
df.describe().round(2)
# Out:
#        RowNumber   CustomerId  CreditScore      Age    Tenure    Balance  \
# count   10000.00     10000.00     10000.00  9880.00  10000.00   10000.00
# mean     5000.50  15690940.57       650.53    38.92      5.01   76485.89
# std      2886.90     71936.19        96.65    10.49      2.89   62397.41
# min         1.00  15565701.00       350.00    18.00      0.00       0.00
# 25%      2500.75  15628528.25       584.00    32.00      3.00       0.00
# 50%      5000.50  15690738.00       652.00    37.00      5.00   97198.54
# 75%      7500.25  15753233.75       718.00    44.00      7.00  127644.24
# max     10000.00  15815690.00       850.00    92.00     10.00  250898.09
#
#        NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary   Exited
# count       10000.00   10000.00        10000.00         10000.00  10000.0
# mean            1.53       0.71            0.52        100090.24      0.2
# std             0.58       0.46            0.50         57510.49      0.4
# ...

# %%
new_df=pd.DataFrame(df,columns=['Age','Tenure'])

# %%
new_df.head()
# Out:
#     Age  Tenure
# 0  42.0       2
# 1  41.0       1
# 2  42.0       8
# 3  39.0       1
# 4  43.0       2

# %%
new_df['Age']=new_df['Age'].fillna(new_df['Age'].mean())
new_df.head()
# Out:
#     Age  Tenure
# 0  42.0       2
# 1  41.0       1
# 2  42.0       8
# 3  39.0       1
# 4  43.0       2

# %%
scaler=MinMaxScaler()
normalised_df=scaler.fit_transform(new_df)
normalised_df
# Out:
# array([[0.32432432, 0.2       ],
#        [0.31081081, 0.1       ],
#        [0.32432432, 0.8       ],
#        ...,
#        [0.24324324, 0.7       ],
#        [0.32432432, 0.3       ],
#        [0.13513514, 0.4       ]], shape=(10000, 2))

# %%
scaler2=StandardScaler()
standardised_df=scaler2.fit_transform(new_df)
standardised_df
# Out:
# array([[ 0.294975  , -1.04175968],
#        [ 0.19904817, -1.38753759],
#        [ 0.294975  ,  1.03290776],
#        ...,
#        [-0.28058597,  0.68712986],
#        [ 0.294975  , -0.69598177],
#        [-1.0480006 , -0.35020386]], shape=(10000, 2))

# %% [markdown]
# # Outlier Treatment
# #### Outliers are the extreme values in the data its is an abnormal observation that deviate from the nom and does not fit in the normal behavior of the data
# ##### Detect outliers using : BOX plot, Histogram, Scatter Plot, Z-score, Interquartile range (values outs of 1.5 time of IQR)
# ##### we handle outlier using following methods
# ###### Remove the outliers
# ###### Replace outlier with suitable values by using following methods: quartile method, inter quartile method
# ###### use that ML method which is not sensitive to outliers
# ###### Like KNN, Decision Tree, SVM, Naive Bayes, Ensemble methods
# #### how to handle
#
# ##### Time series forcasting ( eg: temp of country noting everyday some of the temps could be outliers we should not drop the outliers each data is important )
# ##### When we are dealing with data set where 1 or 2 people as is outlier in that case we can remove or delete them ( check each case )

# %% [markdown]
# #### 3 sigma techniques ( Outlier treatment )  ( 3 Sd technique )
# #### Bases on principles of normal distribution
# #### take is the data lies beyond the range of -3 SD to +3 SD then there are outliers

# %%
import statistics

# %%
df=pd.read_csv(r"C:\Users\DataScience\Desktop\DATA_SCIENCE\EDA\EDA-main\Data\raw_sales.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29580 entries, 0 to 29579
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   datesold      29580 non-null  object
#  1   postcode      29580 non-null  int64
#  2   price         29580 non-null  int64
#  3   propertyType  29580 non-null  object
#  4   bedrooms      29580 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 1.1+ MB

# %%
df.head()
# Out:
#               datesold  postcode   price propertyType  bedrooms
# 0  2007-02-07 00:00:00      2607  525000        house         4
# 1  2007-02-27 00:00:00      2906  290000        house         3
# 2  2007-03-07 00:00:00      2905  328000        house         3
# 3  2007-03-09 00:00:00      2905  380000        house         4
# 4  2007-03-21 00:00:00      2906  310000        house         3

# %%
def find_anomalies(data):
    anomalies=[]
    random_data_std=statistics.stdev(data)
    random_data_mean=statistics.mean(data)
    
    anamoly_cut_off=random_data_std*3
    lower_limit=random_data_mean-anamoly_cut_off
    upper_limit=random_data_mean+anamoly_cut_off

    for outlier in data:
        if outlier < lower_limit or outlier > upper_limit:
            anomalies.append(outlier)
    print(len(anomalies))

# %%
find_anomalies(df['price'])
# Out:
# 461

# %%
## to know the skewness of data
df.price.skew()
# Out:
# np.float64(4.312009366902367)

# %%
import seaborn as sns
sns.kdeplot(df.price)
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
## log transform the data

df['transformed_price']=np.log(df.price)
df.transformed_price.skew()
# Out:
# np.float64(0.47316462699847633)

# %%
find_anomalies(df['transformed_price'])
sns.kdeplot(df.transformed_price)
# Out:
# 266
# <Axes: xlabel='transformed_price', ylabel='Density'>

# %% [markdown]
# ### BOX Plots : visual way of identifying outliers

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
# anythong above 75 or below 35 is considered as outlier

# %%
df.describe()
# Out:
#            postcode         price      bedrooms  transformed_price
# count  29580.000000  2.958000e+04  29580.000000       29580.000000
# mean    2730.249730  6.097363e+05      3.250169          13.244695
# std      146.717292  2.817079e+05      0.951275           0.375214
# min     2600.000000  5.650000e+04      0.000000          10.941996
# 25%     2607.000000  4.400000e+05      3.000000          12.994530
# 50%     2615.000000  5.500000e+05      3.000000          13.217674
# 75%     2905.000000  7.050000e+05      4.000000          13.465953
# max     2914.000000  8.000000e+06      5.000000          15.894952

# %%
# inter quartile range Q3-Q1
list1=[43,54,56,61,62,66,68,69,69,70,71,72,77,78,79,85,87,88,89,93,95,96,98,99,99]
print(len(list1))
# Out:
# 25

# %%
max(list1)
# Out:
# 99

# %%
min(list1)
# Out:
# 43

# %%
statistics.mean(list1)
# Out:
# 76.96

# %%
sorted(list1)
# Out:
# [43,
#  54,
#  56,
#  61,
#  62,
#  66,
#  68,
#  69,
#  69,
#  70,
#  71,
#  72,
#  77,
#  78,
#  79,
#  85,
#  87,
#  88,
#  89,
#  93,
#  95,
#  96,
#  98,
#  99,
#  99]

# %%
# to get the 90th percenticle sort the list and multiply the total number of list by 90% (0.9) we get the index round
# round it up to the nearest whole number 
list2=sorted(list1)
value=round(len(list1)*0.9)
value
# Out:
# 22

# %%
# now say you want to have 20th percentile start by taking 0.20X 25 ( total len)= 5 this is a whole number which tells
# 20th percentile is the avg of 5th and 6th values in the ordered data set (62 and 66)= 64

# %% [markdown]
# ## Handling Invalid Values
# ---
# #### 1. Encode unicode properly
# ##### in case the data is being read as junk characters just try to change encoding
#
# #### 2. Convert incorrect datatypes
# ##### correct the data types for ease of analysis ex: string to int
# #### 3. Correct values that go Beyond Range
# ##### if some values are beyond logical range eg temp cannot go less than -273c or 0 k
# #### 4. Correct worng structure
# ##### value that does not follow a defined structure example: phone number cannot be more than 10 numbers

# %% [markdown]
# TYPES of DATA:
#
# Quantitative
# 1. Discrete (1,2,3,4)
# 2. Continuous (1.3 , 2.4)
#
# Qualitative
# 1. nominal ( no order equal weightage) (male female)
# 2. Ordinal ( has order and raking)  ( 10th class ,inter, Graduation )

# %% [markdown]
# ##Types of analysis
# 1. Univariate analysis ( only deal with 1 variable ): simplest form of analysis
#    - Eg: can be done for numerical / categorical ( mostly categorical )
#    - Total males in the data Categorical data ( distrubution of the column )
#    - Categorical - Distribution , Numerical - Spread
#    - Summary data for numerical data to find min max median 25th percentile and 75th percentile ( box plot plotting ) and IQR ( inter quartile range)
#
#
#
# 2. BiVariate Analysis : analysing of 2 variables ( relationship b/w 2 categorical values / numerical / or both )
#    - Analysing 2 numerical columns age and salary ( plot the scatter plot ) and observe co-variance and co-relation ( +ve, -ve, zero )
#    - Analysing 2 categorical columns country and gender
#    - Analysing 1 numerical and categorical, age and gender
#
#
# 3. MultiVariate Analysis : analysing multiple columns ( 3 or more columns )
#    - only categorical / only numerical or combination

# %% [markdown]
# ### Numerical analysis
# - Dealing with single variable we know their info like mean median 25th quartile 75th quartile min max
# - Dealing with Multiple Variables then we will try to understand the relationship between those 2 variables
# - Dealing with Mutile variables we will find the corr and plot the heat map

# %%
import matplotlib.ticker as mtick
# %matplotlib inline

telco_base_data=pd.read_csv(r"C:\Users\DataScience\Desktop\DATA_SCIENCE\EDA\EDA-main\Data\Churn_Modelling.csv")
telco_base_data.head(2)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender   Age  \
# 0          1    15634602  Hargrave          619    France  Female  42.0
# 1          2    15647311      Hill          608     Spain  Female  41.0
#
#    Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2      0.00              1          1               1
# 1       1  83807.86              1          0               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0

# %%
#univariate analysis
telco_new=telco_base_data[['Geography','Gender','Exited']]
telco_new.head(2)

for i, predictor in enumerate(telco_new.drop(columns=['Exited'])):
    plt.figure()
    sns.countplot(data=telco_new,x=predictor,hue#

# %%
# Bivariate analysis 

# seaborn histplot

sns.histplot(x="Gender",hue="Geography", data=telco_new, stat="count", multiple="dodge")
# Out:
# <Axes: xlabel='Gender', ylabel='Count'>

# %%
telco_new_target1=telco_new.loc[telco_new['Exited']==1]

# %%
sns.histplot(x="Gender",hue="Geography", data=telco_new_target1, stat="count", multiple="dodge")
# Out:
# <Axes: xlabel='Gender', ylabel='Count'>

# %% [markdown]
# #### Numerical analysis
# - Corealation : -1,0,1
# - 1- positive
# - -1 negative
# - 0 no correlation

# %%
telco_base_data.head(1)
ran=telco_base_data.drop(columns=['Geography','Surname','Gender'])
ran.corr()
# Out:
#                  RowNumber  CustomerId  CreditScore       Age    Tenure  \
# RowNumber         1.000000    0.004202     0.005840  0.000620 -0.006495
# CustomerId        0.004202    1.000000     0.005308  0.010372 -0.014883
# CreditScore       0.005840    0.005308     1.000000 -0.002434  0.000842
# Age               0.000620    0.010372    -0.002434  1.000000 -0.009282
# Tenure           -0.006495   -0.014883     0.000842 -0.009282  1.000000
# Balance          -0.009067   -0.012419     0.006268  0.028073 -0.012254
# NumOfProducts     0.007246    0.016972     0.012238 -0.029725  0.013444
# HasCrCard         0.000599   -0.014025    -0.005458 -0.011499  0.022583
# IsActiveMember    0.012044    0.001665     0.025651  0.087632 -0.028362
# EstimatedSalary  -0.005988    0.015271    -0.001384 -0.007203  0.007784
# Exited           -0.016571   -0.006248    -0.027094  0.283596 -0.014001
#
#                   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
plt.figure(figsize=(20,8))
ran.corr()['Exited'].sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: >

# %%
ran.corr()
# Out:
#                  RowNumber  CustomerId  CreditScore       Age    Tenure  \
# RowNumber         1.000000    0.004202     0.005840  0.000620 -0.006495
# CustomerId        0.004202    1.000000     0.005308  0.010372 -0.014883
# CreditScore       0.005840    0.005308     1.000000 -0.002434  0.000842
# Age               0.000620    0.010372    -0.002434  1.000000 -0.009282
# Tenure           -0.006495   -0.014883     0.000842 -0.009282  1.000000
# Balance          -0.009067   -0.012419     0.006268  0.028073 -0.012254
# NumOfProducts     0.007246    0.016972     0.012238 -0.029725  0.013444
# HasCrCard         0.000599   -0.014025    -0.005458 -0.011499  0.022583
# IsActiveMember    0.012044    0.001665     0.025651  0.087632 -0.028362
# EstimatedSalary  -0.005988    0.015271    -0.001384 -0.007203  0.007784
# Exited           -0.016571   -0.006248    -0.027094  0.283596 -0.014001
#
#                   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
plt.figure(figsize=(5,5))
sns.heatmap(ran.corr(),cmap='Paired')
# Out:
# <Axes: >

# %%
telco_base_data.head(5)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender   Age  \
# 0          1    15634602  Hargrave          619    France  Female  42.0
# 1          2    15647311      Hill          608     Spain  Female  41.0
# 2          3    15619304      Onio          502    France  Female  42.0
# 3          4    15701354      Boni          699    France  Female  39.0
# 4          5    15737888  Mitchell          850     Spain  Female  43.0
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
telco_base_data['Age'].value_counts().sort_index(ascending=True).plot()
# Out:
# <Axes: xlabel='Age'>

# %%
telco_base_data_1=telco_base_data.loc[telco_new["Exited"]==1]

# %%
telco_base_data_1['Age'].value_counts().sort_index(ascending=True).plot()
# Out:
# <Axes: xlabel='Age'>

# %%
tot=sns.kdeplot(telco_base_data.Age[(telco_base_data['Exited']==0)],color='red',shade='blue')
tot=sns.kdeplot(telco_base_data.Age[(telco_base_data['Exited']==1)],color='blue',shade='blue')
tot.legend(["No Churn",'Churn'],loc="upper right")
tot.set_ylabel("Density")
tot.set_xlabel("Age")
tot.set_title("Age by Churn / Not Churn ")
# Out:
# C:\Users\DataScience\AppData\Local\Temp\ipykernel_25940\1545052896.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=blue`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   tot=sns.kdeplot(telco_base_data.Age[(telco_base_data['Exited']==0)],color='red',shade='blue')
# C:\Users\DataScience\AppData\Local\Temp\ipykernel_25940\1545052896.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=blue`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   tot=sns.kdeplot(telco_base_data.Age[(telco_base_data['Exited']==1)],color='blue',shade='blue')
# Text(0.5, 1.0, 'Age by Churn / Not Churn ')

# %%
# Out:
# C:\Users\DataScience\AppData\Local\Temp\ipykernel_25940\963304729.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=blue`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   tot=sns.kdeplot(telco_base_data.Age[(telco_base_data['Exited']==1)],color='red',shade='blue')
